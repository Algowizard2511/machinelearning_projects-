# %%
import pandas as pd
import numpy as np
from sklearn.datasets import make_classification
X,y=make_classification(n_samples=100, n_features=2, n_informative=1,n_redundant=0,
                        n_classes=2, n_clusters_per_class=1, random_state=41,hypercube=False,class_sep=20)
Xdf = np.insert(X,0,1,axis=1)

Xdf=pd.DataFrame(X)
ydf=pd.Series(y)

# %%
Xdf.shape
# Out:
# (100, 2)

# %%
import matplotlib.pyplot as plt
plt.scatter(Xdf[0],Xdf[1],c=y,s=50)

# %%
def step(z):
  if z>=0:
    return 1
  else:
    return 0

# %%
# import numpy as np
# import random

# X = np.insert(X, 0, 1, axis=1)

# def perceptron(X, y, lr=0.4):
#     weights = np.ones(X.shape[1])
#     y_pred=[]
#     for i in range(1000):

#         j = random.randint(0, X.shape[0]-1)

#         y_hat = step(np.dot(X[j], weights))
#         y_pred.append(y_hat)
#         print(y_pred)

#         weights = weights - lr * (y[j] - y_hat) * X[j]

#     return weights[0], weights[1:], y_pred

# %%
import random
def perceptron(X, y, lr=0.4):
    X = np.insert(X,0,1,axis=1)
    weights = np.ones(X.shape[1])
    print(weights)

    for i in range(10000):
        j = random.randint(0, X.shape[0]-1)


        y_hat = step(np.dot(X[j], weights))

        weights = weights + lr * (y[j] - y_hat) * X[j]

    y_pred = []
    for i in range(X.shape[0]):
        y_pred.append(step(np.dot(X[i], weights)))

    return weights[0], weights[1:], y_pred

# %%
bias, weights, y_pred = perceptron(X, y)
weights
# Out:
# [1. 1. 1.]
# array([0.98171069, 0.27334424])

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y,y_pred)
# Out:
# 1.0

# %%
print(X.shape)
# Out:
# (100, 2)

# %%
m = -(weights[0]/weights[1])
b = -(bias/weights[1])

# %%
m
# Out:
# np.float64(-3.5914811488289047)

# %%
x_input = np.linspace(-10,10,100)
y_input = m*x_input + b

# %%
y_input
# Out:
# array([ 30.79306468,  30.06751293,  29.34196118,  28.61640943,
#         27.89085769,  27.16530594,  26.43975419,  25.71420245,
#         24.9886507 ,  24.26309895,  23.5375472 ,  22.81199546,
#         22.08644371,  21.36089196,  20.63534022,  19.90978847,
#         19.18423672,  18.45868497,  17.73313323,  17.00758148,
#         16.28202973,  15.55647798,  14.83092624,  14.10537449,
#         13.37982274,  12.654271  ,  11.92871925,  11.2031675 ,
#         10.47761575,   9.75206401,   9.02651226,   8.30096051,
#          7.57540877,   6.84985702,   6.12430527,   5.39875352,
#          4.67320178,   3.94765003,   3.22209828,   2.49654653,
#          1.77099479,   1.04544304,   0.31989129,  -0.40566045,
#         -1.1312122 ,  -1.85676395,  -2.5823157 ,  -3.30786744,
#         -4.03341919,  -4.75897094,  -5.48452269,  -6.21007443,
#         -6.93562618,  -7.66117793,  -8.38672967,  -9.11228142,
#         -9.83783317, -10.56338492, -11.28893666, -12.01448841,
# ...

# %%
y_input2
# Out:
# array([ 30.79306468,  30.06751293,  29.34196118,  28.61640943,
#         27.89085769,  27.16530594,  26.43975419,  25.71420245,
#         24.9886507 ,  24.26309895,  23.5375472 ,  22.81199546,
#         22.08644371,  21.36089196,  20.63534022,  19.90978847,
#         19.18423672,  18.45868497,  17.73313323,  17.00758148,
#         16.28202973,  15.55647798,  14.83092624,  14.10537449,
#         13.37982274,  12.654271  ,  11.92871925,  11.2031675 ,
#         10.47761575,   9.75206401,   9.02651226,   8.30096051,
#          7.57540877,   6.84985702,   6.12430527,   5.39875352,
#          4.67320178,   3.94765003,   3.22209828,   2.49654653,
#          1.77099479,   1.04544304,   0.31989129,  -0.40566045,
#         -1.1312122 ,  -1.85676395,  -2.5823157 ,  -3.30786744,
#         -4.03341919,  -4.75897094,  -5.48452269,  -6.21007443,
#         -6.93562618,  -7.66117793,  -8.38672967,  -9.11228142,
#         -9.83783317, -10.56338492, -11.28893666, -12.01448841,
# ...

# %%
np.linspace(-10,10,100)
# Out:
# array([-10.        ,  -9.7979798 ,  -9.5959596 ,  -9.39393939,
#         -9.19191919,  -8.98989899,  -8.78787879,  -8.58585859,
#         -8.38383838,  -8.18181818,  -7.97979798,  -7.77777778,
#         -7.57575758,  -7.37373737,  -7.17171717,  -6.96969697,
#         -6.76767677,  -6.56565657,  -6.36363636,  -6.16161616,
#         -5.95959596,  -5.75757576,  -5.55555556,  -5.35353535,
#         -5.15151515,  -4.94949495,  -4.74747475,  -4.54545455,
#         -4.34343434,  -4.14141414,  -3.93939394,  -3.73737374,
#         -3.53535354,  -3.33333333,  -3.13131313,  -2.92929293,
#         -2.72727273,  -2.52525253,  -2.32323232,  -2.12121212,
#         -1.91919192,  -1.71717172,  -1.51515152,  -1.31313131,
#         -1.11111111,  -0.90909091,  -0.70707071,  -0.50505051,
#         -0.3030303 ,  -0.1010101 ,   0.1010101 ,   0.3030303 ,
#          0.50505051,   0.70707071,   0.90909091,   1.11111111,
#          1.31313131,   1.51515152,   1.71717172,   1.91919192,
# ...

# %%
plt.figure(figsize=(10,6))
plt.plot(x_input,y_input,color='red',linewidth=3)
plt.scatter(Xdf.iloc[:,0], Xdf.iloc[:,1], c=y, cmap='winter', s=100)
plt.ylim(-3,2)
# Out:
# (-3.0, 2.0)

# %% [markdown]
# NOW USING SIGMOID FUNCTION

# %%
import random
def perceptron(X, y, lr=0.4):
    X = np.insert(X,0,1,axis=1)
    weights = np.ones(X.shape[1])

    for i in range(10000):
        j = random.randint(0, X.shape[0]-1)


        y_hat = sigmoid(np.dot(X[j], weights))

        weights = weights + lr * (y[j] - y_hat) * X[j]

    y_pred = []
    for i in range(X.shape[0]):
        y_pred.append(step(np.dot(X[i], weights)))

    return weights[0], weights[1:], y_pred

# %%
def sigmoid(z):
  return 1/(1+np.exp(-z))

# %%
bias, weights, y_pred = perceptron(X, y)

# %%
m1 = -(weights[0]/weights[1])
b1 = -(bias/weights[1])

# %%
x_input1 = np.linspace(-10,10,100)
y_input1 = m1*x_input + b1

# %%
plt.figure(figsize=(10,6))
plt.plot(x_input,y_input,color='black',linewidth=3)
plt.plot(x_input1,y_input1,color='red',linewidth=3)
plt.scatter(Xdf.iloc[:,0], Xdf.iloc[:,1], c=y, cmap='winter', s=100)
plt.ylim(-3,2)
# Out:
# (-3.0, 2.0)

# %%
from sklearn.linear_model import LogisticRegression
lg=LogisticRegression()
lg.fit(X,y)
# Out:
# LogisticRegression()

# %%
lg.coef_
# Out:
# array([[2.36679363, 0.02300492]])

# %%
lg.intercept_
# Out:
# array([3.13571596])

# %%
m2 = -(lg.coef_[0][0]/lg.coef_[0][1])
b2 = -(lg.intercept_/lg.coef_[0][1])

# %%
x_input2 = np.linspace(-10,10,100)
y_input2 = m*x_input2 + b

# %%
plt.figure(figsize=(10,6))
plt.plot(x_input,y_input,color='green',linewidth=3)
plt.plot(x_input1,y_input1,color='red',linewidth=3)
plt.plot(x_input2,y_input2,color='black',linewidth=3)
plt.scatter(Xdf.iloc[:,0], Xdf.iloc[:,1], c=y, cmap='winter', s=100)
plt.ylim(-3,2)
# Out:
# (-3.0, 2.0)

# %%
print("Green:", y_input[:5])
print("Red:", y_input1[:5])
print("Black:", y_input2[:5])
# Out:
# Green: [30.79306468 30.06751293 29.34196118 28.61640943 27.89085769]
# Red: [191.75537715 187.33895555 182.92253395 178.50611235 174.08969074]
# Black: [30.79306468 30.06751293 29.34196118 28.61640943 27.89085769]
